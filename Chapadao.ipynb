# %%
# Temas disponíveis
# !jt -l
# Out:
# Available Themes:
#    chesterish
#    grade3
#    gruvboxd
#    gruvboxl
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl

# %%
# Selecionar tema
# !jt -t grade3

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd

# %matplotlib inline

df = pd.read_csv('2019_analise_chapadao.csv', sep = ',', encoding = 'utf-8')
tn = pd.read_csv('chapadao_tn.csv', sep = ',', encoding = 'utf-8')
colunas = df.columns

plt.style.use('seaborn-ticks')

# %%
def porcentagem(variavel):
    tamanho = variavel.sum()

    soma = valores = 0
    
    print()

    for i in variavel * 100 / tamanho:
        print(f'{variavel.index[valores]:20} --> {variavel[valores]:^3} --> {i:.0f}%')
        soma += i
        valores += 1

    print('-' * 20)
    print(f'Total: {soma}%')
    print(f'{tamanho} peças')

# %%
# Matérias-primas
df_silexito = df[df['Matéria-prima'] == 'Silexito']
df_quartzo_leitoso = df[df['Matéria-prima'] == 'Quartzo leitoso']
df_indeterminado = df[df['Matéria-prima'] == 'Indeterminado']
df_arenito = df[df['Matéria-prima'] == 'Arenito']
df_arenito_silicificado = df[df['Matéria-prima'] == 'Arenito Silicificado']
df_basalto = df[df['Matéria-prima'] == 'Basalto']
df_quartzo_hialino = df[df['Matéria-prima'] == 'Quartzo Hialino']
df_quartzito = df[df['Matéria-prima'] == 'Quartzito']
df_calcedonia = df[df['Matéria-prima'] == 'Calcedônia']

# %%
df['Matéria-prima'].value_counts()
# Out:
# Silexito                1018
# Quartzo leitoso          414
# Indeterminado            380
# Arenito                  257
# Arenito Silicificado     163
# Basalto                  103
# Quartzo Hialino           33
# Quartzito                 11
# Calcedônia                 2
# Name: Matéria-prima, dtype: int64

# %% [markdown]
# ## Silexito

# %%
df_silexito['Tipo de instrumento'].value_counts().plot.barh()
plt.xlabel('Quantidade')
plt.xticks([0,3,6,9,12,15,18])
plt.title('Tipos de instrumento');

# %% [markdown]
# ## Quartzo leitoso

# %%
df_quartzo_leitoso['Tipo de instrumento'].value_counts().plot.barh()
plt.xlabel('Quantidade');
plt.title('Tipos de instrumento');

# %% [markdown]
# ## Arenito silicificado

# %%
df_arenito_silicificado['Tipo de instrumento'].value_counts().plot.barh()
plt.xlabel('Quantidade')
plt.xticks([0,1,2,3])
plt.title('Tipos de instrumentos');

# %% [markdown]
# # Gráficos de distribuição vertical e horizontal dos vestígios líticos

# %%
# Limites do terreno
tn_x = tn['X']
tn_y = tn['Y']
tn_z = tn['Z']

# Níveis superficiais e em subsuperfície
superficie = df['Nível'] == 'Superfície'
sub = df['Nível'] != 'Superfície'

# PN's
x1 = df_silexito['X'][superficie]
y1 = df_silexito['Y'][superficie]
z1 = df_silexito['Z'][superficie]
x2 = df_quartzo_leitoso['X'][superficie]
y2 = df_quartzo_leitoso['Y'][superficie]
z2 = df_quartzo_leitoso['Z'][superficie]
x4 = df_arenito['X'][superficie]
y4 = df_arenito['Y'][superficie]
z4 = df_arenito['Z'][superficie]
x5 = df_arenito_silicificado['X'][superficie]
y5 = df_arenito_silicificado['Y'][superficie]
z5 = df_arenito_silicificado['Z'][superficie]
x6 = df_basalto['X'][superficie]
y6 = df_basalto['Y'][superficie]
z6 = df_basalto['Z'][superficie]
x7 = df_quartzo_hialino['X'][superficie]
y7 = df_quartzo_hialino['Y'][superficie]
z7 = df_quartzo_hialino['Z'][superficie]
x8 = df_quartzito['X'][superficie]
y8 = df_quartzito['Y'][superficie]
z8 = df_quartzito['Z'][superficie]

x1_sub = df_silexito['X'][sub]
y1_sub = df_silexito['Y'][sub]
z1_sub = df_silexito['Z'][sub]
x2_sub = df_quartzo_leitoso['X'][sub]
y2_sub = df_quartzo_leitoso['Y'][sub]
z2_sub = df_quartzo_leitoso['Z'][sub]
x3_sub = df_indeterminado['X'][sub] 
y3_sub = df_indeterminado['Y'][sub]
z3_sub = df_indeterminado['Z'][sub]
x5_sub = df_arenito_silicificado['X'][sub]
y5_sub = df_arenito_silicificado['Y'][sub]
z5_sub = df_arenito_silicificado['Z'][sub]
x6_sub = df_basalto['X'][sub]
y6_sub = df_basalto['Y'][sub]
z6_sub = df_basalto['Z'][sub]
x8_sub = df_quartzito['X'][sub]
y8_sub = df_quartzito['Y'][sub]
z8_sub = df_quartzito['Z'][sub]

x200 = [655892023,  655892047,      655894066,         655893993,        655892023] #NW,SW,SE,NE
x100 = [655892023,  655892047,      655894066 - 1000,  655893993 - 1000, 655892023]
x050 = [655892023,  655892047,      655894066 - 1000,  655893993 - 1000, 655892023]
x025 = [655892023,  655892047,      655894066 - 1500,  655893993 - 1500, 655892023]

y200 = [6946221998, 6946219998,     6946220010,         6946222006, 6946221998] # NW, SW, SE, NE
y100 = [6946221998, 6946219998 + 1000, 6946220010 + 1000,  6946222006, 6946221998]
y050 = [6946221998, 6946219998 + 1500, 6946220010 + 1500,  6946222006, 6946221998]
y025 = [6946221998, 6946219998 + 1500, 6946220010 + 1500,  6946222006, 6946221998]

nv0 = [688969, 688988, 689099, 689078, 688969]
nv1 = [688870, 688895, 688999, 688980, 688870]
nv2 = [688780, 688792, 688902, 688870, 688780]
nv3 = [688700, 688696, 688731, 688720, 688700]
nv4 = [688605, 688606, 688609, 688610, 688605]
nv5 = [688460, 688480, 688510, 688510, 688460]
nv6 = [688385, 688391, 688410, 688405, 688385]
nv7 = [688301, 688335, 688367, 688332, 688301]
nv8 = [688220, 688223, 688270, 688250, 688220]
nv9 = [688118, 688141, 688241, 688215, 688118]

# %%
# %matplotlib notebook
# %matplotlib notebook
fig = plt.figure(figsize = (13,9))
ax = fig.add_subplot(111, projection='3d')

x1_ = df['X'][superficie]
y1_ = df['Y'][superficie]
z1_ = df['Z'][superficie]

ax.plot(tn_x, tn_y, tn_z, marker = 'o', linewidth = 0.3, markersize = 1, c = 'darkgrey',
        label='Pontos do terreno')
ax.plot(x1_, y1_, z1_, marker = 'o' , linewidth = 0 , markersize = 3, c = 'black',
       label='Materiais líticos')

ax.set_xlabel('Longitude')
ax.set_xticks([655850000, 655900000, 655950000, 656000000])
ax.set_xticklabels(['655850', '655900', '655950', '655600'])

ax.set_ylabel('Latitude')
ax.set_yticks([6946180000, 6946220000, 6946260000])
ax.set_yticklabels(['6946180', '6946220', '6946260'])

ax.set_zlabel('Altitude')
ax.set_zticks([700000, 695000, 690000, 685000, 680000])
ax.set_zticklabels(['700', '695', '690', '685', '680'])

plt.legend(loc = 'upper left', markerscale = 3, frameon = True, facecolor = 'floralwhite');
# Out:
# <img src="data:image/png;base64,..." width="936">

# %%
# %matplotlib notebook
# %matplotlib notebook

fig = plt.figure(figsize = (14,9))
ax = fig.add_subplot(111, projection='3d')

ax.plot(x1,y1,z1,label='Silexito',marker='^',linewidth=0,markersize=3,color='black')
# ax.plot(x2,y2,z2,label='Quartzo leitoso',marker='<',linewidth=0,markersize=3,color='SlateGray')
# ax.plot(x4,y4,z4,label='Arenito',marker='o',linewidth=0,markersize=3,color='MediumVioletRed')
# ax.plot(x5,y5,z5,label='A. silicificado',marker='>',linewidth=0,markersize=3,color='darkorange')
# ax.plot(x6,y6,z6,label='Basalto',marker='o',linewidth=0,markersize=3,color='lightgreen')
# ax.plot(x7,y7,z7,label='Quartzo hialino',marker='o',linewidth=0,markersize=3,color='red')
# ax.plot(x8,y8,z8,label='Quartzito',marker='o',linewidth=0,markersize=3,color='blue')

ax.set_xlabel('Longitude')
ax.set_xticks([655870000, 655890000, 655910000, 655930000])
ax.set_xticklabels(['655870', '655890', '655910', '655930'])

ax.set_ylabel('Latitude')
ax.set_yticks([6946220000, 6946240000])
ax.set_yticklabels(['6946220', '6946240'])

ax.set_zlabel('Altitude')
ax.set_zticks([690000, 688000, 686000])
ax.set_zticklabels(['690', '688', '686'])
# ax.set_zlim(688000,689500)

plt.legend(loc='upper left');
# Out:
# <img src="data:image/png;base64,..." width="1008">

# %%
# %matplotlib notebook
# %matplotlib notebook

fig = plt.figure(figsize = (14,9))
ax = fig.add_subplot(111, projection='3d')

# Anotações
font_dict = {'family': 'serif', 'color': 'black', 'size': 9}
ax.text(x100[2] + 300, y100[2], nv3[2] + 50, s = 'Materiais não plotados', fontdict = font_dict)
ax.text(x200[1] - 300, y200[1], nv0[1], s = 'Nível 0', fontdict = font_dict)
ax.text(x200[1] - 300, y200[1], nv1[1], s = 'Nível 1', fontdict = font_dict)
ax.text(x200[1] - 300, y200[1], nv2[1], s = 'Nível 2', fontdict = font_dict)
ax.text(x100[1] - 300, y100[1], nv3[1], s = 'Nível 3', fontdict = font_dict)
ax.text(x100[1] - 300, y100[1], nv4[1], s = 'Nível 4', fontdict = font_dict)
ax.text(x100[1] - 300, y100[1], nv5[1], s = 'Nível 5', fontdict = font_dict)
ax.text(x100[1] - 300, y100[1], nv6[1], s = 'Nível 6', fontdict = font_dict)
ax.text(x100[1] - 300, y100[1], nv7[1], s = 'Nível 7', fontdict = font_dict)
ax.text(x050[1] - 300, y050[1], nv8[1], s = 'Nível 8', fontdict = font_dict)
ax.text(x025[1] - 300, y025[1], nv9[1], s = 'Nível 9', fontdict = font_dict)

# Materiais plotados
ax.scatter(x1_sub, y1_sub, z1_sub, label = 'Silexito', color = 'blue')
ax.scatter(x2_sub, y2_sub, z2_sub, color = 'black')
ax.scatter(x3_sub, y3_sub, z3_sub, label = 'Indeterminado', color = 'yellow')
ax.scatter(x6_sub, y6_sub, z6_sub, label = 'Arenito silicificado', color = 'orange')
ax.scatter(x5_sub, y5_sub, z5_sub, label = 'Basalto', color = 'lightgreen')
ax.scatter(x8_sub, y8_sub, z8_sub, label = 'Quartzito')

# Materiais sem procedência
# 50-60
ax.scatter(x100[2] + 300, y100[2], nv6[2] + 100, color = 'black')
# 40-50
ax.scatter(x100[2] + 300, y100[2], nv5[2] + 100, color = 'blue')
ax.scatter(x100[2] + 400, y100[2], nv5[2] + 100, color = 'orange')
ax.scatter(x100[2] + 500, y100[2], nv5[2] + 100, color = 'black')
ax.scatter(x100[2] + 600, y100[2], nv5[2] + 100, color = 'purple')
# 30-40
ax.scatter(x100[2] + 300, y100[2], nv4[2] + 100, color = 'blue')
ax.scatter(x100[2] + 400, y100[2], nv4[2] + 100, color = 'orange')
ax.scatter(x100[2] + 500, y100[2], nv4[2] + 100, color = 'lightgreen')
ax.scatter(x100[2] + 600, y100[2], nv4[2] + 100, color = 'black', label = 'Quartzo leitoso')
ax.scatter(x100[2] + 700, y100[2], nv4[2] + 100, color = 'mediumorchid', label = 'Basalto')

# Quadrículas
ax.plot(x200, y200, nv0, color = '#7a5a3e', linewidth = 1.0, label = 'Níveis artificiais')
ax.plot(x200, y200, nv1, color = '#5c3011', linewidth = 1.0)
ax.plot(x200, y200, nv2, color = '#5c3011', linewidth = 1.0)
ax.plot(x100, y100, nv3, color = '#673003', linewidth = 1.0) # linestyle = 'dashed' ou 'Dashed'
ax.plot(x100, y100, nv4, color = '#673003', linewidth = 1.0)
ax.plot(x100, y100, nv5, color = '#673003', linewidth = 1.0)
ax.plot(x100, y100, nv6, color = '#8b4d14', linewidth = 1.0)
ax.plot(x100, y100, nv7, color = '#8b4d14', linewidth = 1.0)
ax.plot(x050, y050, nv8, color = '#8b4d14', linewidth = 1.0)
ax.plot(x025, y025, nv9, color = '#be5701', linewidth = 1.0)

# Formatação do gráfico
ax.set_xticks([655892500, 655893500])
ax.set_xticklabels(['655892.5', '655893.5'])

ax.set_yticks([]) # 6946220500, 6946221000, 6946221500
# ax.set_yticklabels(['6946220.5', '6946221.0', '6946221.5'])

ax.set_zticks([689000, 688200, 688400, 688600, 688800])
ax.set_zticklabels(['689.0','688.2','688.4','688.6','688.8'])

plt.legend(loc = 'upper left');
# Out:
# <img src="data:image/png;base64,..." width="1008">

# %%
fig = plt.figure(figsize = (10,7))
ax = fig.add_subplot(111)

# Definição das variáveis
x = [655892006, 655895010]
y = [6946223996, 6946218032]
x_a1 = [655892013, 655892052, 655894066, 655893993, 655892013]
y_a1 = [6946222040, 6946219998, 6946220010, 6946222006, 6946222040]
x_ = df['X'][superficie]
y_ = df['Y'][superficie]
a = [655892023,  655892047,          655894066 - 1000,  655893993 - 1000, 655892023]
b = [6946221998, 6946219998 + 1000, 6946220010 + 1000,  6946222006,       6946221998]

# Criação dos gráficos
ax.plot(x_,y_,linewidth=0, marker='o', markersize=3,color='lightblue',label='Materiais líticos')
ax.plot(x, y, label = 'Tradagens', color = 'black', linewidth = 0, marker='o', markersize = 8)
ax.plot(x_a1, y_a1, label = 'Área de escavação', color = 'DarkSlateGray', linewidth = 3)
ax.plot(a, b, color = 'Darkslategray')

# Anotações
font_dict = {'family': 'serif', 'color': 'black', 'size': 11, 'weight': 'medium'}
ax.text(x[0] + 300, y[0], s = 'Tradagem 1', fontdict = font_dict)
ax.text(x[1] + 300, y[1], s = 'Tradagem 2', fontdict = font_dict)
ax.text(x_a1[3] + 200, y_a1[3], s = 'Área de escavação', fontdict = font_dict)
ax.text(a[2] - 1000, b[2] + 500, s = 'NW', fontdict = font_dict)

# Formatação dos gráficos
ax.set_xlabel('Longitude')
ax.set_xticks([655886000, 655890000, 655894000, 655898000, 655902000])
ax.set_xticklabels(['', '655890', '655894', '655898', ''])
ax.set_xlim(left = 655886000, right = 655902000)

ax.set_ylabel('Latitude')
ax.set_yticks([6946214000, 6946218000, 6946222000, 6946226000, 6946230000])
ax.set_yticklabels(['', '6946218', '6946222', '6946226', ''])
ax.set_ylim([6946214000, 6946230000])

plt.grid(True)
plt.legend(loc = 'upper left', markerscale = 1, frameon = True, facecolor = 'floralwhite');

# %%
# %matplotlib notebook
# %matplotlib notebook
fig = plt.figure(figsize = (12,9))
ax = fig.add_subplot(111, projection='3d')

u_i_s = df_silexito['Classe artefatual'] == 'Instrumento'
u_n_s = df_silexito['Classe artefatual'] == 'Núcleo'
u_n_b = df_basalto['Classe artefatual'] == 'Percutor'
u_i_a = df_arenito_silicificado['Classe artefatual'] == 'Instrumento'
u_i_q = df_quartzo_leitoso['Classe artefatual'] == 'Instrumento'
u_pref_q = df_quartzo_leitoso['Classe artefatual'] == 'Pré-forma'

u_s = df_silexito['Nível'] != 'Superfície'
u_b = df_basalto['Nível'] != 'Superfície'
u_a = df_arenito_silicificado['Nível'] != 'Superfície'
u_q = df_quartzo_leitoso['Nível'] != 'Superfície'

a,b,c=df_silexito[u_i_s & u_s]['X'],df_silexito[u_i_s & u_s]['Y'],df_silexito[u_i_s & u_s]['Z']
d,e,f=df_silexito[u_n_s & u_s]['X'], df_silexito[u_n_s & u_s]['Y'], df_silexito[u_n_s & u_s]['Z']
g,h,i=df_basalto[u_n_b & u_b]['X'], df_basalto[u_n_b & u_b]['Y'], df_basalto[u_n_b & u_b]['Z']
j,k,l=df_arenito_silicificado[u_i_a & u_a]['X'], df_arenito_silicificado[u_i_a & u_a]['Y'], df_arenito_silicificado[u_i_a & u_a]['Z']
m,n,o=df_quartzo_leitoso[u_i_q & u_q]['X'], df_quartzo_leitoso[u_i_q & u_q]['Y'], df_quartzo_leitoso[u_i_q & u_q]['Z']
p,q,r=df_quartzo_leitoso[u_pref_q & u_q]['X'], df_quartzo_leitoso[u_pref_q & u_q]['Y'], df_quartzo_leitoso[u_pref_q & u_q]['Z']

ax.plot(x200, y200, nv0, color = '#7a5a3e', linewidth = 0.5, label = 'Níveis artificiais')
ax.plot(x200, y200, nv1, color = '#5c3011', linewidth = 0.5)
ax.plot(x200, y200, nv2, color = '#5c3011', linewidth = 0.5)
ax.plot(x100, y100, nv3, color = '#673003', linewidth = 0.5)

ax.scatter(a, b, c, color = 'k', s = 100, label = 'Instr. de silexito', marker = '*')
ax.scatter(d, e, f, color = 'k', s = 80, label = 'Núcleos de silexito', marker = 's')
ax.scatter(g, h, i, color = 'y', s = 80, label = 'Percutor de basalto')
ax.scatter(j, k, l, color = 'slateblue', s = 100, label = 'Instr. de arenito silicificado',
           marker = '*')
ax.scatter(m, n, o, color = 'red', s = 100, label = 'Instr. de quartzo leitoso',
           marker = '*')
ax.scatter(p, q, r, color = 'red', s = 80, label = 'Pré-forma de quartzo leitoso', marker='^')

# Formatação do gráfico
ax.set_xticks([655892000, 655893000, 655894000])
ax.set_xticklabels(['655892', '655893', '655894'])
ax.set_yticks([6946221000])
ax.set_yticklabels(['6946221.0'])
ax.set_zticks([688700, 688800, 688900, 689000, 689100])
ax.set_zticklabels(['688.7','688.8','688.9','689.0','689.1'])

ax.legend(loc = 'upper left');
# Out:
# <img src="data:image/png;base64,..." width="864">

# %%
fig = plt.figure(figsize = (12,9))

mask1 = df_silexito['Classe artefatual'] == 'Instrumento'
mask2 = df_silexito['Classe artefatual'] == 'Núcleo'
mask3 = df_silexito['Classe artefatual'] == 'Pré-forma'
mask4 = df_silexito['Nível'] == 'Superfície'
mask5 = df_quartzo_leitoso['Classe artefatual'] == 'Instrumento'
mask6 = df_quartzo_leitoso['Classe artefatual'] == 'Pré-forma'
mask7 = df_quartzo_leitoso['Classe artefatual'] == 'Núcleo'
mask8 = df_quartzo_leitoso['Classe artefatual'] == 'Núcleo sobre lasca unipolar'
mask9 = df_quartzo_leitoso['Nível'] == 'Superfície'
mask10 = df_quartzito['Classe artefatual'] == 'Instrumento'
mask11 = df_quartzito['Nível'] == 'Superfície'
mask12 = df_indeterminado['Classe artefatual'] == 'Instrumento'
mask13 = df_indeterminado['Classe artefatual'] == 'Pré-forma'
mask14 = df_indeterminado['Nível'] == 'Superfície'
mask15 = df_basalto['Classe artefatual'] == 'Percutor'
mask16 = df_basalto['Classe artefatual'] == 'Instrumento'
mask17 = df_basalto['Classe artefatual'] == 'Instrumento fragmentado'
mask18 = df_basalto['Nível'] == 'Superfície'
mask19 = df_arenito_silicificado['Classe artefatual'] == 'Pré-forma'
mask20 = df_arenito_silicificado['Nível'] == 'Superfície'
mask21 = df_basalto['Classe artefatual'] == 'Bruto'
mask22 = df_basalto['Classe artefatual'] == 'Detrito'

a_test, b_test = df_silexito[mask1 & mask4]['X'], df_silexito[mask1 & mask4]['Y']
c_test, d_test = df_silexito[mask2 & mask4]['X'], df_silexito[mask2 & mask4]['Y']
e_test, f_test = df_silexito[mask3 & mask4]['X'], df_silexito[mask3 & mask4]['Y']
g_test, h_test = df_quartzo_leitoso[mask5 & mask9]['X'], df_quartzo_leitoso[mask5 & mask9]['Y']
i_test, j_test = df_quartzo_leitoso[mask6 & mask9]['X'], df_quartzo_leitoso[mask6 & mask9]['Y']
k_test, l_test = df_quartzo_leitoso[mask7 & mask9]['X'], df_quartzo_leitoso[mask7 & mask9]['Y']
m_test, n_test = df_quartzito[mask10 & mask11]['X'], df_quartzito[mask10 & mask11]['Y']
o_test, p_test = df_indeterminado[mask12 & mask14]['X'], df_indeterminado[mask12 & mask14]['Y']
q_test, r_test = df_indeterminado[mask13 & mask14]['X'], df_indeterminado[mask13 & mask14]['Y']
s_test, t_test = df_basalto[mask15 & mask18]['X'], df_basalto[mask15 & mask18]['Y']
u_test, v_test = df_basalto[mask16 & mask18]['X'], df_basalto[mask16 & mask18]['Y']
w_test, x_test = df_basalto[mask17 & mask18]['X'], df_basalto[mask17 & mask18]['Y']
xi, yi = df_basalto[mask21 & mask18]['X'], df_basalto[mask21 & mask18]['Y']
xii, yii = df_basalto[mask22 & mask18]['X'], df_basalto[mask22 & mask18]['Y']
y_t,z_t=df_arenito_silicificado[mask19&mask20]['X'],df_arenito_silicificado[mask19&mask20]['Y']

plt.plot(x_a1, y_a1, label = 'Área de escavação', color = 'orange', linewidth = 1)

plt.scatter(xi, yi, color ='yellow', label = None)

plt.scatter(xii, yii, label = 'Detritos e materiais brutos de basalto', color ='yellow')
plt.scatter(g_test, h_test, label = 'Instr. de quartzo leitoso', color = 'red', marker = '*')
plt.scatter(i_test, j_test, label = 'Pré-forma de quartzo leitoso', color = 'red', marker = '^')
plt.scatter(k_test, l_test, label = 'Núcleo de quartzo leitoso', color = 'red', marker = 's')
plt.scatter(c_test, d_test, label = 'Núcleos de silexito', color = 'k', marker = 's')
plt.scatter(e_test, f_test, label = 'Pré-forma de silexito', color = 'k', marker = '^')
plt.scatter(a_test, b_test, label ='Instr. de silexito', color = 'k', marker = '*')
plt.scatter(m_test, n_test, label = 'Instr. de quartzito', color = 'c', marker = '*')
plt.scatter(o_test, p_test, label = 'Instr. de matéria-prima ind.', color = 'g', marker = '*')
plt.scatter(q_test, r_test, label='Pré-forma de matéria-prima ind.', color = 'g', marker = '^')
plt.scatter(s_test, t_test, label = 'Instr.de basalto', color = 'y', s = 150)
plt.scatter(u_test, v_test, label = None, color = 'y', s = 150)
plt.scatter(w_test, x_test, label = 'Percutor de basalto', color = 'y')
plt.scatter(y_t,z_t,label='Pré-forma de arenito silicificado',color='slateblue', marker = '^')

# Formatação do gráfico
plt.xticks([655870000, 655880000, 655890000, 655900000, 655910000],
           labels = ['655870', '655880', '655890','655900','655910'])
plt.yticks([6946200000, 6946210000, 6946220000, 6946230000],
          labels = ['6946200', '6946210', '6946220', '6946230'])
# plt.yticklabels(['6946221.0'])
# plt.zticks([688700, 688800, 688900, 689000, 689100])
# plt.zticklabels(['688.7','688.8','688.9','689.0','689.1'])

plt.legend(loc = 'best')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid()
plt.title('Distribuição de vestígios líticos em superfície');

# %%
# Get rid of colored axes planes
# First remove fill
# ax.xaxis.pane.fill = False
# ax.yaxis.pane.fill = False
# ax.zaxis.pane.fill = False

# Now set color to white (or whatever is "invisible")
# ax.xaxis.pane.set_edgecolor('w')
# ax.yaxis.pane.set_edgecolor('w')
# ax.zaxis.pane.set_edgecolor('w')

# ax.grid(False)

# %% [markdown]
# # Xmind

# %%
matp = df_silexito

# Córtex
c_inex = matp['Tipo de córtex'] == 'Inexistente'
c_sxo = matp['Tipo de córtex'] == 'Seixo'
c_ind = matp['Tipo de córtex'] == 'Indeterminado'
c_bloco = matp['Tipo de córtex'] == 'Bloco'
c_plaq = matp['Tipo de córtex'] == 'Plaqueta'
c_cris = matp['Tipo de córtex'] == 'Cristal'
c_sxot = matp['Tipo de córtex'] == 'Seixo tabular de grande porte'

# Técnica de transformação
tec_uni = matp['Técnica de transformação'] == 'Unipolar'
tec_ind = matp['Técnica de transformação'] == 'Indeterminada'
sem_trans = matp['Técnica de transformação'] == 'Sem transformação'
tec_bi = matp['Técnica de transformação'] == 'Bipolar'
tec_vest = matp['Técnica de transformação'] == 'Vestígios de utilização'
tec_nat = matp['Técnica de transformação'] == 'Natural'
tec_pico = matp['Técnica de transformação'] == 'Picoteamento'

# Classes
l_cort = matp['Classe artefatual'] == 'Lasca cortical'
l_deb = matp['Classe artefatual'] == 'Lasca de debitagem'
l_form = matp['Classe artefatual'] == 'Lasca de formatação'
l_ret = matp['Classe artefatual'] == 'Lasca de retoque'
l_fr = matp['Classe artefatual'] == 'Lasca fragmentada'
instr = matp['Classe artefatual'] == 'Instrumento'
natu = matp['Classe artefatual'] == 'Natural'
pref = matp['Classe artefatual'] == 'Pré-forma'
nucl = matp['Classe artefatual'] == 'Núcleo'
instr_f = matp['Classe artefatual'] == 'Instrumento fragmentado'
l_bipo = matp['Classe artefatual'] == 'Lasca bipolar'
perc = matp['Classe artefatual'] == 'Percutor'
nucl_b = matp['Classe artefatual'] == 'Núcleo bipolar'
nucl_l = matp['Classe artefatual'] == 'Núcleo sobre lasca unipolar'
brut = matp['Classe artefatual'] == 'Bruto'

# Instrumentos
unifacial = matp['Tipo de instrumento'] == 'Unifacial'
p_unifacial = matp['Tipo de instrumento'] == 'Ponta unifacial'
o_unifacial = matp['Tipo de instrumento'] == 'Instrumento unifacial com gume obtuso'
bifacial = matp['Tipo de instrumento'] == 'Bifacial'
grande_porte = matp['Tipo de instrumento'] == 'Instrumento de grande porte fragmentado'
l_retoc = matp['Tipo de instrumento'] == 'Lasca retocada'
abras = matp['Tipo de instrumento'] == 'Instrumento com vestígios de abrasão'
ins_ind = matp['Tipo de instrumento'] == 'Indeterminado'
pre_f = matp['Tipo de instrumento'] == 'Pré-forma de instrumento bifacial'

# Suportes
suport_ind = matp['Base de modificação primária'] == 'Indeterminado'
lasc_uni = matp['Base de modificação primária'] == 'Lasca unipolar'
plaqueta = matp['Base de modificação primária'] == 'Plaqueta'
seixo = matp['Base de modificação primária'] == 'Seixo'
lasca_b = matp['Base de modificação primária'] == 'lasca bipolar'

# Núcleos
nucleo_1 = matp['Tipo de núcleo'] == 'Núcleo com um plano de percussão definido'
nucleo_2 = matp['Tipo de núcleo'] == 'Núcleo com 2 planos de percussão em ângulo'
nucleo_3 = matp['Tipo de núcleo'] == 'Nucleiforme bipolar'

# %%
# instrumentos
lista_instrumento = [matp[c_inex&tec_uni&instr]['Tipo de instrumento'].value_counts(),
        matp[c_inex&tec_uni&instr&bifacial]['Base de modificação primária'].value_counts(),
        matp[c_inex&tec_uni&instr&bifacial & suport_ind]['Tipo de modificação'].value_counts(),
        matp[c_inex&tec_uni&instr&bifacial]['Posição'].value_counts(),
        matp[c_inex&tec_uni&instr&bifacial]['Extensão'].value_counts(),
        matp[c_inex&tec_uni&instr&bifacial]['Ângulo'].value_counts(),
        matp[c_inex&tec_uni&instr&bifacial]['Delineamento'].value_counts(),
        matp[c_inex&tec_uni&instr&bifacial]['Repartição'].value_counts()]
# Executar função de porcentagem
variavel = lista_instrumento[0]

# Núcleos
lista_nucleo =  [matp[c_ind & tec_uni & nucl]['Tipo de núcleo'].value_counts(),
    matp[c_ind & tec_uni & nucl & nucleo_3]['Tipo de plataforma de percussão'].value_counts()]
# Executar função de porcentagem
# variavel = lista_nucleo[0]

# Lascas
lista_lasca = [matp[c_inex & tec_uni & l_fr]['Talão'].value_counts(),
               matp[c_inex & tec_uni & l_fr]['Preparação no talão'].value_counts(),
               matp[c_inex & tec_uni & l_fr]['Forma do bulbo'].value_counts(),
               matp[c_inex & tec_uni & l_fr]['Número de cicatrizes'].value_counts(),
               matp[c_inex & tec_uni & l_fr]['Direção das cicatrizes'].value_counts()]
# Executar função de porcentagem
# variavel = lista_lasca[0]

# Geral
lista_geral =       [matp['Tipo de córtex'].value_counts(),
                     matp[c_inex]['Técnica de transformação'].value_counts(),
                     matp[c_inex & tec_uni]['Classe artefatual'].value_counts()]
# Executar função de porcentagem
# variavel = lista_geral[2]

porcentagem(variavel)
# Out:
# Bifacial             --> 18  --> 75%
# Lasca retocada       -->  2  --> 8%
# Instrumento unifacial com gume obtuso -->  1  --> 4%
# Unifacial            -->  1  --> 4%
# Instrumento com vestígios de abrasão -->  1  --> 4%
# Ponta unifacial      -->  1  --> 4%
# --------------------
# Total: 100.00000000000001%
# 24 peças

# %%
# Consulta individual de peças

consulta = [matp[c_inex & tec_uni & instr][[
                                                        'Tipo de instrumento',
                                                        'Tipo de modificação',
                                                        'Base de modificação primária',
                                                        'Posição',
                                                        'Extensão',
                                                        'Ângulo',
                                                        'Delineamento',
                                                        'Repartição',
                                                        'Marcas de uso']],
            matp[c_inex & tec_uni & l_fr][[
                                           'Talão',
                                           'Preparação no talão',
                                           'Forma do bulbo',
                                           'Número de cicatrizes',
                                           'Direção das cicatrizes']],
            matp[c_sxo & tec_uni & nucl][[
                                          'Tipo de núcleo',
                                          'Tipo de plataforma de percussão']]]

consulta[2]
# Out:
#                                  Tipo de núcleo  \
# 1529  Núcleo com um plano de percussão definido
# 1813  Núcleo com um plano de percussão definido
#
#      Tipo de plataforma de percussão
# 1529                  acortical liso
# 1813                  acortical liso

# %%
matplotlib -v
# Out:
# UsageError: unrecognized arguments: -v
